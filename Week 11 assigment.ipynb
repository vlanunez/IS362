# %% [markdown]
# # Week 11
#
#  Your task is to:
#
# 1. Choose one of the New York Times APIs
# 2. Construct an interface in Python to read in the JSON data
# 3. Transform it into a pandas DataFrame
#
# I chose to query the New York Times API by article search

# %%
import numpy as np
import pandas as pd
import requests
import json as json

#set some pandas options controling output format
pd.set_option('display.notebook_repr_html',True) 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# this is a simple funtion that takes some basic arguments for the New York Times API and returns the JSON respnse
def NYTSearch(strQuery, strStartDate, strEndDate):
    # Set the URL for the API
    url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'
    dictParams = {'api-key': "76GgTJdfNpk359GHXWYWqCF2F2O0AAkq",
                 'q': strQuery,
                 'begin_date': strStartDate,
                 'end_date': strEndDate,
                 'page': 1}
    

    return(requests.get(url, params = dictParams))

# %%
# send the request to the New York Times API
response = NYTSearch("article search", 20210101, 20220101)

# %%
jsonresults = response.json()['response']['docs']

# %%
results = pd.io.json.json_normalize(jsonresults)
# Out:
# C:\Users\Vlad\AppData\Local\Temp/ipykernel_4160/1667805544.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   results = pd.io.json.json_normalize(jsonresults)

# %%
results
# Out:
#                                             abstract  \
# 0  When Gottlieb’s Bakery reopened in Savannah, G...
# 1  Major League Baseball now wants to welcome Neg...
# 2  Mental health experts assumed that people of a...
# 3  Some mothers are seeking alternatives, worried...
# 4  The idea came from a sliver of news about a Ne...
# 5  The government rejected the accounts of women ...
# 6  A Google fact box singled out Kannada, a langu...
# 7  As inexperienced hikers hit the trails, there ...
# 8  A House committee sought briefings from search...
# 9  In response to Times articles, the search gian...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2021/01/19/dining/jewi...
# 1  https://www.nytimes.com/2021/03/23/magazine/ne...
# 2  https://www.nytimes.com/2021/11/18/well/mind/s...
# 3  https://www.nytimes.com/2021/03/11/nyregion/bi...
# 4  https://www.nytimes.com/2021/06/14/insider/sho...
# 5  https://www.nytimes.com/2021/07/10/world/middl...
# ...
